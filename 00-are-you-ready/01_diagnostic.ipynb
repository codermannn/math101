# %% [markdown]
# # 🧪 Prerequisites Diagnostic
#
# **Before you begin, let's check your readiness.**
#
# This notebook tests the Python and math fundamentals you'll need. No traps — just honest calibration so you know where to focus.
#
# ---
#
# ### Scoring
# - **90–100%**: You're ready. Jump to `TOOLS_PRIMER/`.
# - **70–89%**: You can proceed but review the topics you missed.
# - **Below 70%**: Strengthen fundamentals first (resources linked at the end).
#
# ---

# %%
from math101.testing import check_answer, check_complexity, difficulty_banner, score_report

results = []  # Track all answers

# %% [markdown]
# ## ⚠️ Common Wrong Intuition
# *(Describe the wrong way most people first think about this. Show why it breaks, and explain how the correct intuition rectifies it.)*

# %% [markdown]
# ## Part 1: Python Fundamentals

# %%
# Q1: List comprehension
# What does this produce?
result = [x**2 for x in range(5) if x % 2 == 0]

your_answer = ___  # Replace ___ with your prediction (a list)
results.append(check_answer(your_answer, [0, 4, 16],
    question='What does [x**2 for x in range(5) if x % 2 == 0] produce?',
    hint='range(5) gives [0,1,2,3,4]. Filter evens, then square.'))

# %%
# Q2: Recursion
def mystery(n):
    if n <= 1:
        return 1
    return n * mystery(n - 1)

your_answer = ___  # What does mystery(5) return?
results.append(check_answer(your_answer, 120,
    question='What does mystery(5) return?',
    hint='This is the factorial function: 5×4×3×2×1'))

# %%
# Q3: Dictionary operations
d = {'a': 1, 'b': 2, 'c': 3}
result = sum(d.values())

your_answer = ___  # What is result?
results.append(check_answer(your_answer, 6,
    question='What is sum({"a": 1, "b": 2, "c": 3}.values())?',
    hint='d.values() gives [1, 2, 3]'))

# %%
# Q4: Nested loops — how many times does 'count' increment?
count = 0
for i in range(4):
    for j in range(3):
        count += 1

your_answer = ___  # What is count?
results.append(check_answer(your_answer, 12,
    question='How many times does the inner loop body execute? (4 outer × 3 inner)',
    hint='Outer runs 4 times, inner runs 3 times each → 4×3 = 12'))

# %%
# Q5: Slicing
arr = [10, 20, 30, 40, 50]
result = arr[1:4]

your_answer = ___  # What is result?
results.append(check_answer(your_answer, [20, 30, 40],
    question='What is [10, 20, 30, 40, 50][1:4]?',
    hint='Slice from index 1 (inclusive) to 4 (exclusive)'))

# %% [markdown]
# ## Part 2: Math Fundamentals

# %%
import numpy as np

# Q6: Logarithms
# log₂(1024) = ?
your_answer = ___
results.append(check_answer(your_answer, 10,
    question='What is log₂(1024)?',
    hint='2^? = 1024. Try: 2^10 = 1024'))

# %%
# Q7: Summation
# What is 1 + 2 + 3 + ... + 100?
# (There's a formula for this!)
your_answer = ___
results.append(check_answer(your_answer, 5050,
    question='What is 1 + 2 + 3 + ... + 100?',
    hint='Gauss formula: n(n+1)/2 = 100×101/2'))

# %%
# Q8: Exponents
# 2^10 = ?
your_answer = ___
results.append(check_answer(your_answer, 1024,
    question='What is 2^10?',
    hint='2, 4, 8, 16, 32, 64, 128, 256, 512, 1024'))

# %%
# Q9: Factorials
# 6! = ?
your_answer = ___
results.append(check_answer(your_answer, 720,
    question='What is 6! (6 factorial)?',
    hint='6×5×4×3×2×1 = 720'))

# %%
# Q10: Growth intuition
# Which grows faster for large n: n² or 2ⁿ?
your_answer = ___  # Type 'n^2' or '2^n'
results.append(check_answer(your_answer, '2^n',
    question='Which grows faster for large n: n² or 2ⁿ?',
    hint='Try n=20: n²=400, 2ⁿ=1,048,576. Exponential always wins.'))

# %% [markdown]
# ## Results

# %%
score_report(results)

correct = sum(results)
total = len(results)
pct = correct / total * 100

if pct >= 90:
    print('\n🚀 You\'re ready! Head to 01-seeing-with-code/visualization_toolbox.ipynb')
elif pct >= 70:
    print('\n📖 Mostly ready. Review these resources for the topics you missed:')
    print('   Python: https://docs.python.org/3/tutorial/')
    print('   Math:   https://www.khanacademy.org/math/algebra')
else:
    print('\n📚 Strengthen fundamentals first:')
    print('   Python: https://www.learnpython.org/')
    print('   Math:   https://www.khanacademy.org/math/precalculus')
    print('   Then come back — this lab will be here!')

# %% [markdown]
# ## The Feynman Technique
# Explain [this concept] in plain English to someone who has never seen it. Write it in the cell below. Then check: did you use any jargon you can't define from scratch? If yes, go back.

# %% [markdown]
# *(Write your explanation here...)*

# %% [markdown]
# ## Review
# - **Q:**
# - **A:**
#
# - **Q:**
# - **A:**

# %% [markdown]
# ## The Takeaway
# > **The one thing to carry forward is:** *(Write the insight, not the formula)*
