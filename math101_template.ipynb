# %% [markdown]
# # [Topic Name]
#
# ## The Hook
# [Opening question or puzzle here. Approachable but slightly surprising.]

# %% [markdown]
# ## The Playground
# Run the cells below and use the sliders to explore. Don't worry about the math yet.

# %%
# Code with ipywidgets sliders for exploration
import numpy as np
import matplotlib.pyplot as plt
from ipywidgets import interact, FloatSlider

# TODO: Add interactive exploration code here

# %% [markdown]
# ## ⚠️ Common Wrong Intuition
# [Describe the wrong way most people first think about this, why it breaks, and how the correct intuition fixes it.]

# %% [markdown]
# ## The Pattern
# *What did you notice?*
# [Point at the pattern that emerged from the playground. Focus on the Aha! moment.]

# %% [markdown]
# ## The Explanation
# 1. **Analogy**: This works like [familiar thing].
# 2. **Diagram**: [Load-bearing visual below]
# 3. **Example**: [Fully worked, annotated example from scratch]
# 4. **Plain English**: [Describe without jargon]
# 5. **Technical**: [Introduce formal notation and definition]

# %% [markdown]
# ## The Proof / Why It's True
# Now let's see why this had to be true. [Visual proof over symbolic if possible]

# %% [markdown]
# ## 🔬 Break-It Lab (The Exercise)
# 1. **Break it**: What happens if you set X to 0 or push it to extremes?
# 2. **Extend it**: Can you make this work in a broader case (e.g., 3D)?
# 3. **Connect it**: How does this relate to [previous concept in repo]?

# %% [markdown]
# ## The Feynman Technique
# Explain [this concept] in plain English to someone who has never seen it. Write it in the cell below. Then check: did you use any jargon you can't define from scratch? If yes, go back.

# %% [markdown]
# *(Write your explanation here)*

# %% [markdown]
# ## Review
# Q: [Bare minimum question to verify understanding]
# A: [Answer]
#
# Q: [Second bare minimum question]
# A: [Answer]
#
# Q: [Third bare minimum question]
# A: [Answer]

# %% [markdown]
# ## The Takeaway
# **The one thing to carry forward is:** [The insight, not the formula]
